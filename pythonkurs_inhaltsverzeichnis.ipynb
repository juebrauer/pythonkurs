# %% [markdown]
# # Python-Kurs: Inhaltsverzeichnis
#
# Dies ist der zentrale Einstiegspunkt für die Materialien.
#
# Alle Themen des Python-Kurses werden hier als separate Notebooks verlinkt.
#
# [Einführung in Python und Jupyter Notebooks](beispielnotebook.ipynb)
# - Was ist Python?
# - Was ist Jupyter?
# - Erste Schritte mit Jupyter Notebooks
# - Übungsaufgaben
#
# [Python-Grundlagen](beispielnotebook.ipynb)
# - Variablen und Datentypen
# - Grundlegende Operatoren
# - Strings und ihre Methoden
# - Übungsaufgaben
#
# [Kontrollstrukturen](beispielnotebook.ipynb)
# - Bedingte Anweisungen (if, elif, else)
# - Schleifen (for, while)
# - Übungsaufgaben
#
# Listen und Tupel
# - Was sind Listen und Tupel?
# - Methoden und Operationen
# - Listen-Comprehensions
# - Übungsaufgaben
#
# Dictionaries und Sets
# - Einführung in Dictionaries
# - Methoden und Operationen von Dictionaries
# - Einführung in Sets
# - Übungsaufgaben
#
# Funktionen in Python
# - Funktionsdefinitionen
# - Parameter und Rückgabewerte
# - Lambda-Funktionen
# - Übungsaufgaben
#
# Module und Pakete
# - Importieren von Modulen
# - Erstellen eigener Module
# - Verwendung von pip zum Installieren von Paketen
# - Übungsaufgaben
#
# Dateioperationen
# - Dateien lesen und schreiben
# - Umgang mit Ausnahmen (try, except)
# - Übungsaufgaben
#
# Objektorientierte Programmierung (OOP)
# - Klassen und Objekte
# - Vererbung und Polymorphismus
# - Spezielle Methoden (__init__, __str__)
# - Übungsaufgaben
#
# Fehlerbehandlung und Ausnahmen
# - Was sind Ausnahmen?
# - Eigene Ausnahmen erstellen
# - try, except, finally
# - Übungsaufgaben
#
# Python und Datenbanken
# - SQLite mit Python
# - CRUD-Operationen
# - Übungsaufgaben
#
# Einführung in die Datenanalyse mit Pandas
# - Datenstrukturen in Pandas
# - Datenmanipulation und -analyse
# - Übungsaufgaben
#
# Datenvisualisierung mit Matplotlib und Seaborn
# - Grundlagen der Datenvisualisierung
# - Verschiedene Diagrammtypen
# - Übungsaufgaben
#
# Weitere fortgeschrittene Themen
# - Generatoren und Iteratoren
# - Dekoratoren
# - List-, Set- und Dict-Comprehensions
# - Übungsaufgaben
#
# Abschlussprojekt: Ein kleines Python-Projekt von A bis Z
# - Ideenfindung
# - Planung und Umsetzung
# - Präsentation des Projekts
# - Übungsaufgaben
